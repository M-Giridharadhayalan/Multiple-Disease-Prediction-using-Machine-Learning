# %%
import pandas as pd
import numpy as np

# %%
ldf=pd.read_csv("D:\Data Science\Project-3\Employee_Attrition\.venv\liver_data.csv")

# %%
ldf.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
ldf.shape
# Out:
# (583, 11)

# %%
ldf.columns
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio', 'Dataset'],
#       dtype='object')

# %%
ldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         583 non-null    int64
#  1   Gender                      583 non-null    object
#  2   Total_Bilirubin             583 non-null    float64
#  3   Direct_Bilirubin            583 non-null    float64
#  4   Alkaline_Phosphotase        583 non-null    int64
#  5   Alamine_Aminotransferase    583 non-null    int64
#  6   Aspartate_Aminotransferase  583 non-null    int64
#  7   Total_Protiens              583 non-null    float64
#  8   Albumin                     583 non-null    float64
#  9   Albumin_and_Globulin_Ratio  579 non-null    float64
#  10  Dataset                     583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
#Target is Dataset and Classification problem

# %%
ldf.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  583.000000       583.000000        583.000000            583.000000
# mean    44.746141         3.298799          1.486106            290.576329
# std     16.189833         6.209522          2.808498            242.937989
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.500000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     58.000000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                583.000000                  583.000000      583.000000
# mean                  80.713551                  109.910806        6.483190
# ...

# %%
#EDA
#Distribution of Numerical Columns
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ldf.hist(figsize=(15,15),xrot=-45,bins=10)
plt.show()

# %%
ldf['Dataset'] = ldf['Dataset'].apply(lambda x: 0 if x == 2 else 1)

# %%
ldf['Dataset'].value_counts()
# Out:
# Dataset
# 1    416
# 0    167
# Name: count, dtype: int64

# %%
ldf.describe(include=['object'])
# Out:
#        Gender
# count     583
# unique      2
# top      Male
# freq      441

# %%
plt.figure (figsize=(5,5))
sns.countplot(y='Gender',data=ldf, palette='hot')
# Out:
# C:\Users\MGiri\AppData\Local\Temp\ipykernel_3692\4278710582.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='Gender',data=ldf, palette='hot')
# <Axes: xlabel='count', ylabel='Gender'>

# %%
ldf['Gender'] = ldf['Gender'].map({'Male': 0, 'Female': 1})

# %%
ldf['Gender'].value_counts()
# Out:
# Gender
# 0    441
# 1    142
# Name: count, dtype: int64

# %%
ldf.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65       1              0.7               0.1                   187
# 1   62       0             10.9               5.5                   699
# 2   62       0              7.3               4.1                   490
# 3   58       0              1.0               0.4                   182
# 4   72       0              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
ldf
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65       1              0.7               0.1                   187
# 1     62       0             10.9               5.5                   699
# 2     62       0              7.3               4.1                   490
# 3     58       0              1.0               0.4                   182
# 4     72       0              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60       0              0.5               0.1                   500
# 579   40       0              0.6               0.1                    98
# 580   52       0              0.8               0.2                   245
# 581   31       0              1.3               0.5                   184
# 582   38       0              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %%
ldf.corr()
# Out:
#                                  Age    Gender  Total_Bilirubin  \
# Age                         1.000000 -0.056560         0.011763
# Gender                     -0.056560  1.000000        -0.089291
# Total_Bilirubin             0.011763 -0.089291         1.000000
# Direct_Bilirubin            0.007529 -0.100436         0.874618
# Alkaline_Phosphotase        0.080425  0.027496         0.206669
# Alamine_Aminotransferase   -0.086883 -0.082332         0.214065
# Aspartate_Aminotransferase -0.019910 -0.080336         0.237831
# Total_Protiens             -0.187461  0.089121        -0.008099
# Albumin                    -0.265924  0.093799        -0.222250
# Albumin_and_Globulin_Ratio -0.216408  0.003424        -0.206267
# Dataset                     0.137351 -0.082416         0.220208
#
#                             Direct_Bilirubin  Alkaline_Phosphotase  \
# Age                                 0.007529              0.080425
# ...

# %%
#Positive - one feature increases wit other
#Negative-one feature increases wit other decreaes
#weak relation - closer to zero

# %%
plt.figure(figsize=(10,10))
sns.heatmap(ldf.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Feature Correlation Heatmap')
plt.tight_layout()
plt.show()

# %%
corr_matrix = ldf.corr()
print("\nHighly Positive:")
print(corr_matrix[corr_matrix > 0.6].stack().drop_duplicates())

print("\nHighly Negative:")
print(corr_matrix[corr_matrix < -0.2].stack().drop_duplicates())
# Out:
# Highly Positive:
# Age                       Age                           1.000000
# Total_Bilirubin           Direct_Bilirubin              0.874618
# Alamine_Aminotransferase  Aspartate_Aminotransferase    0.791966
# Total_Protiens            Albumin                       0.784053
# Albumin                   Albumin_and_Globulin_Ratio    0.689632
# dtype: float64
#
# Highly Negative:
# Age                   Albumin                      -0.265924
#                       Albumin_and_Globulin_Ratio   -0.216408
# Total_Bilirubin       Albumin                      -0.222250
#                       Albumin_and_Globulin_Ratio   -0.206267
# Direct_Bilirubin      Albumin                      -0.228531
#                       Albumin_and_Globulin_Ratio   -0.200125
# Alkaline_Phosphotase  Albumin_and_Globulin_Ratio   -0.234166
# dtype: float64

# %%
ldf.duplicated
# Out:
# <bound method DataFrame.duplicated of      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65       1              0.7               0.1                   187
# 1     62       0             10.9               5.5                   699
# 2     62       0              7.3               4.1                   490
# 3     58       0              1.0               0.4                   182
# 4     72       0              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60       0              0.5               0.1                   500
# 579   40       0              0.6               0.1                    98
# 580   52       0              0.8               0.2                   245
# 581   31       0              1.3               0.5                   184
# 582   38       0              1.0               0.3                   216
#
# ...

# %%
ldf.duplicated().sum()
# Out:
# np.int64(13)

# %%
ldf=ldf.drop_duplicates()

# %%
ldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 570 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         570 non-null    int64
#  1   Gender                      570 non-null    int64
#  2   Total_Bilirubin             570 non-null    float64
#  3   Direct_Bilirubin            570 non-null    float64
#  4   Alkaline_Phosphotase        570 non-null    int64
#  5   Alamine_Aminotransferase    570 non-null    int64
#  6   Aspartate_Aminotransferase  570 non-null    int64
#  7   Total_Protiens              570 non-null    float64
#  8   Albumin                     570 non-null    float64
#  9   Albumin_and_Globulin_Ratio  566 non-null    float64
#  10  Dataset                     570 non-null    int64
# dtypes: float64(5), int64(6)
# memory usage: 53.4 KB

# %%
ldf.shape
# Out:
# (570, 11)

# %%
#checking outlier in Aspartate_Aminotransferase	
sns.boxenplot(ldf.Aspartate_Aminotransferase)
# Out:
# <Axes: ylabel='Aspartate_Aminotransferase'>

# %%
ldf.columns
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio', 'Dataset'],
#       dtype='object')

# %%
sns.boxenplot(ldf.Alkaline_Phosphotase)
# Out:
# <Axes: ylabel='Alkaline_Phosphotase'>

# %%
sns.boxenplot(ldf.Total_Bilirubin)
# Out:
# <Axes: ylabel='Total_Bilirubin'>

# %%
ldf.Aspartate_Aminotransferase.sort_values(ascending=False).head()
# Out:
# 135    4929
# 117    2946
# 118    1600
# 207    1500
# 199    1050
# Name: Aspartate_Aminotransferase, dtype: int64

# %%
#removing outlier 
ldf = ldf [ldf.Aspartate_Aminotransferase<=3000]

# %%
ldf.Aspartate_Aminotransferase.sort_values(ascending=False).head()
# Out:
# 117    2946
# 118    1600
# 207    1500
# 199    1050
# 119    1050
# Name: Aspartate_Aminotransferase, dtype: int64

# %%
ldf.shape
# Out:
# (569, 11)

# %%
ldf = ldf [ldf.Aspartate_Aminotransferase<=2500]

# %%
ldf.Aspartate_Aminotransferase.sort_values(ascending=False).head()
# Out:
# 118    1600
# 207    1500
# 119    1050
# 199    1050
# 47      960
# Name: Aspartate_Aminotransferase, dtype: int64

# %%
ldf.shape
# Out:
# (568, 11)

# %%
ldf.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Dataset                       0
# dtype: int64

# %%
ldf=ldf.dropna(how='any')

# %%
ldf.shape
# Out:
# (564, 11)

# %%
ldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 564 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         564 non-null    int64
#  1   Gender                      564 non-null    int64
#  2   Total_Bilirubin             564 non-null    float64
#  3   Direct_Bilirubin            564 non-null    float64
#  4   Alkaline_Phosphotase        564 non-null    int64
#  5   Alamine_Aminotransferase    564 non-null    int64
#  6   Aspartate_Aminotransferase  564 non-null    int64
#  7   Total_Protiens              564 non-null    float64
#  8   Albumin                     564 non-null    float64
#  9   Albumin_and_Globulin_Ratio  564 non-null    float64
#  10  Dataset                     564 non-null    int64
# dtypes: float64(5), int64(6)
# memory usage: 52.9 KB

# %%
#Machine Learning 
lx=ldf.drop('Dataset',axis=1)
ly=ldf.Dataset

# %%
from sklearn.model_selection import train_test_split
lx_train,lx_test,ly_train,ly_test =train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
#Data Standardization 
train_mean = lx_train.mean()
train_std = lx_train.std()

# %%
lx_train = (lx_train -train_mean)/train_std

# %%
lx_train.describe()
# Out:
#                 Age        Gender  Total_Bilirubin  Direct_Bilirubin  \
# count  4.510000e+02  4.510000e+02     4.510000e+02      4.510000e+02
# mean  -7.778946e-17 -7.877414e-17    -1.969353e-17     -7.877414e-17
# std    1.000000e+00  1.000000e+00     1.000000e+00      1.000000e+00
# min   -2.474771e+00 -5.570968e-01    -4.460322e-01     -5.024692e-01
# 25%   -7.650820e-01 -5.570968e-01    -3.992580e-01     -4.664530e-01
# 50%    2.870242e-02 -5.570968e-01    -3.680751e-01     -4.304369e-01
# 75%    8.224868e-01 -5.570968e-01    -1.030209e-01     -7.027541e-02
# max    2.776418e+00  1.791040e+00     1.116958e+01      6.556696e+00
#
#        Alkaline_Phosphotase  Alamine_Aminotransferase  \
# count          4.510000e+02              4.510000e+02
# mean           3.938707e-18              3.741772e-17
# std            1.000000e+00              1.000000e+00
# min           -9.504531e-01             -4.147385e-01
# 25%           -4.828891e-01             -3.309332e-01
# ...

# %%
x_test.describe()
# Out:
#                 Age        Gender  Total_Bilirubin  Direct_Bilirubin  \
# count  1.130000e+02  1.130000e+02     1.130000e+02      1.130000e+02
# mean   1.788147e-16  5.698490e-17    -1.964997e-18      1.277248e-17
# std    1.000000e+00  1.000000e+00     1.000000e+00      1.000000e+00
# min   -2.162353e+00 -6.121301e-01    -4.719273e-01     -4.469064e-01
# 25%   -5.203283e-01 -6.121301e-01    -4.019663e-01     -4.143044e-01
# 50%   -1.509008e-02 -6.121301e-01    -3.844760e-01     -3.817025e-01
# 75%    7.427673e-01  1.619183e+00    -1.920832e-01     -2.186927e-01
# max    2.447946e+00  1.619183e+00     5.159935e+00      5.486649e+00
#
#        Alkaline_Phosphotase  Alamine_Aminotransferase  \
# count          1.130000e+02              1.130000e+02
# mean           2.456246e-17              3.340494e-17
# std            1.000000e+00              1.000000e+00
# min           -7.359341e-01             -4.154939e-01
# 25%           -4.411211e-01             -3.336322e-01
# ...

# %%
#logistic regression 
logr = LogisticRegression()
logr.fit(lx_train,ly_train)
# Out:
# LogisticRegression()

# %%
print(accuracy_score(ly_train, logr.predict(lx_train)))
# Out:
# 0.7184035476718403

# %%
logr_acc = accuracy_score(ly_test, logr.predict(lx_test))
print(logr_acc)
# Out:
# 0.7522123893805309

# %%
print (confusion_matrix(ly_test,logr.predict(lx_test)))
# Out:
# [[ 0 28]
#  [ 0 85]]

# %%
print (classification_report(ly_test,logr.predict(lx_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        28
#            1       0.75      1.00      0.86        85
#
#     accuracy                           0.75       113
#    macro avg       0.38      0.50      0.43       113
# weighted avg       0.57      0.75      0.65       113
# d:\Data Science\Project-3\Employee_Attrition\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\Data Science\Project-3\Employee_Attrition\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN=KNeighborsClassifier()
KNN.fit(lx_train,ly_train)
# Out:
# KNeighborsClassifier()

# %%
print(accuracy_score(ly_train, KNN.predict(lx_train)))
KNN_acc = accuracy_score(ly_test, KNN.predict(lx_test))
print(KNN_acc)
print (confusion_matrix(ly_test,KNN.predict(lx_test)))
print (classification_report(ly_test,KNN.predict(lx_test)))
# Out:
# 0.8203991130820399
# 0.7522123893805309
# [[ 0 28]
#  [ 0 85]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        28
#            1       0.75      1.00      0.86        85
#
#     accuracy                           0.75       113
#    macro avg       0.38      0.50      0.43       113
# weighted avg       0.57      0.75      0.65       113
# d:\Data Science\Project-3\Employee_Attrition\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
DTC = DecisionTreeClassifier()
DTC.fit(lx_train,ly_train)
# Out:
# DecisionTreeClassifier()

# %%
print(accuracy_score(ly_train, DTC.predict(lx_train)))
DTC_acc = accuracy_score(ly_test, DTC.predict(lx_test))
print(DTC_acc)
print (confusion_matrix(ly_test,DTC.predict(lx_test)))
print (classification_report(ly_test,DTC.predict(lx_test)))
# Out:
# 1.0
# 0.24778761061946902
# [[28  0]
#  [85  0]]
#               precision    recall  f1-score   support
#
#            0       0.25      1.00      0.40        28
#            1       0.00      0.00      0.00        85
#
#     accuracy                           0.25       113
#    macro avg       0.12      0.50      0.20       113
# weighted avg       0.06      0.25      0.10       113
# d:\Data Science\Project-3\Employee_Attrition\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
#Over Fitting of Training Result - Hyperparameter Tuning 

grid_parameters = {
    'criterion':['gini','entropy'],
    'max_depth':[3,5,7,10],
    'splitter':['best','random'],
    'min_samples_leaf':[1,2,3,5,7],
    'min_samples_split':[2,3,5,7],
    'max_features':['sqrt','log2']
}

grid_search_DTC=GridSearchCV(DTC,grid_parameters,cv=5,n_jobs=-1,verbose=1)
grid_search_DTC.fit(lx_train,ly_train)
# Out:
# Fitting 5 folds for each of 640 candidates, totalling 3200 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 7, 10],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 3, 5, 7],
#                          'min_samples_split': [2, 3, 5, 7],
#                          'splitter': ['best', 'random']},
#              verbose=1)

# %%
grid_search_DTC.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 3,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 3,
#  'min_samples_split': 3,
#  'splitter': 'best'}

# %%
grid_search_DTC.best_score_
# Out:
# np.float64(0.7339926739926741)

# %%
DTC = DecisionTreeClassifier(criterion= 'gini', max_depth = 3, max_features = 'sqrt', min_samples_leaf =5, min_samples_split = 7, splitter ='best')
DTC.fit(lx_train,ly_train)
# Out:
# DecisionTreeClassifier(max_depth=3, max_features='sqrt', min_samples_leaf=5,
#                        min_samples_split=7)

# %%
print(accuracy_score(ly_train, DTC.predict(lx_train)))
DTC_acc = accuracy_score(ly_test, DTC.predict(lx_test))
print(DTC_acc)
print (confusion_matrix(ly_test,DTC.predict(lx_test)))
print (classification_report(ly_test,DTC.predict(lx_test)))
# Out:
# 0.7317073170731707
# 0.7522123893805309
# [[ 0 28]
#  [ 0 85]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        28
#            1       0.75      1.00      0.86        85
#
#     accuracy                           0.75       113
#    macro avg       0.38      0.50      0.43       113
# weighted avg       0.57      0.75      0.65       113
# d:\Data Science\Project-3\Employee_Attrition\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
rand_for = RandomForestClassifier(criterion= 'gini', max_depth = 3, max_features = 'sqrt', min_samples_leaf =5, min_samples_split = 7)
rand_for.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=3, min_samples_leaf=5, min_samples_split=7)

# %%
print(accuracy_score(ly_train, rand_for.predict(lx_train)))
rand_for_acc = accuracy_score(ly_test, rand_for.predict(lx_test))
print(rand_for_acc)
print (confusion_matrix(ly_test,rand_for.predict(lx_test)))
print (classification_report(ly_test,rand_for.predict(lx_test)))
# Out:
# 0.7782705099778271
# 0.7522123893805309
# [[ 0 28]
#  [ 0 85]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        28
#            1       0.75      1.00      0.86        85
#
#     accuracy                           0.75       113
#    macro avg       0.38      0.50      0.43       113
# weighted avg       0.57      0.75      0.65       113
# d:\Data Science\Project-3\Employee_Attrition\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
#models data frame 
lmodels = pd.DataFrame({ 'Model':['Logistic', 'kneigh','deci_trees','rand_forest'],
                       'score':[logr_acc,KNN_acc,DTC_acc,rand_for_acc]})
lmodels.sort_values(by='score',ascending=False)
# Out:
#          Model     score
# 0     Logistic  0.752212
# 1       kneigh  0.752212
# 2   deci_trees  0.752212
# 3  rand_forest  0.752212

# %%
import pickle
with open("liver_new1.pkl", "wb") as l:
    pickle.dump(logr_acc, l)
