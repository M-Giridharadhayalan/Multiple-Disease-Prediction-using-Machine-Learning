# %%
import pandas as pd
import numpy as np

# %%
pdf=pd.read_csv('D:\Data Science\Project-3\Employee_Attrition\.venv\parkinsons_data.csv')

# %%
pdf.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
pdf.columns
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
pdf.shape
# Out:
# (195, 24)

# %%
#Checking Type of Problem - Classification or Regression
pdf['status'].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
pdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
pdf.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
pdf.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
pdf
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# ..              ...          ...           ...           ...             ...
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
# ...

# %%
pdf.groupby('status').mean(numeric_only=True)
# Out:
#         MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# status
# 0        181.937771    223.636750    145.207292        0.003866
# 1        145.180762    188.441463    106.893558        0.006989
#
#         MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# status
# 0               0.000023  0.001925  0.002056    0.005776      0.017615
# 1               0.000051  0.003757  0.003900    0.011273      0.033658
#
#         MDVP:Shimmer(dB)  ...  MDVP:APQ  Shimmer:DDA       NHR        HNR  \
# status                    ...
# 0               0.162958  ...  0.013305     0.028511  0.011483  24.678750
# 1               0.321204  ...  0.027600     0.053027  0.029211  20.974048
#
#             RPDE       DFA   spread1   spread2        D2       PPE
# status
# 0       0.442552  0.695716 -6.759264  0.160292  2.154491  0.123017
# 1       0.516816  0.725408 -5.333420  0.248133  2.456058  0.233828
#
# [2 rows x 22 columns]

# %%
pdf = pdf.drop('name', axis=1)

# %%
pdf
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
#Machine Learning preprocessing
x=pdf.drop('status',axis=1)
y=pdf.status

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
#data standardisation 
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
scalar.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train = scalar.transform(x_train)
x_test = scalar.transform(x_test)

# %%
x_train
# Out:
# array([[-0.61443971, -0.61780655,  0.04127923, ...,  0.5029092 ,
#         -0.40751375, -0.68223215],
#        [-0.04034851, -0.35415175, -0.98088597, ..., -0.28958497,
#         -0.65415395, -0.42818012],
#        [ 1.52915319,  0.43526029, -0.54728793, ...,  1.93233825,
#          1.357776  ,  0.13991703],
#        ...,
#        [-0.84047179, -0.61957265, -0.1354869 , ...,  1.21146574,
#         -0.45451571, -0.2250194 ],
#        [ 0.3875642 ,  0.83251984, -0.8922878 , ...,  2.03352299,
#          1.45315514,  0.77558086],
#        [ 0.52924939, -0.10330959,  1.11583374, ..., -0.37674221,
#          0.37893111, -0.39314388]], shape=(156, 22))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
#logistic regression 
logi = LogisticRegression()
logi.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
print(accuracy_score(y_train, logi.predict(x_train)))
logi_acc = accuracy_score(y_test, logi.predict(x_test))
print(logi_acc)
print (confusion_matrix(y_test,logi.predict(x_test)))
print (classification_report(y_test,logi.predict(x_test)))
# Out:
# 0.8589743589743589
# 0.8461538461538461
# [[ 7  3]
#  [ 3 26]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70        10
#            1       0.90      0.90      0.90        29
#
#     accuracy                           0.85        39
#    macro avg       0.80      0.80      0.80        39
# weighted avg       0.85      0.85      0.85        39

# %%
Dtc = DecisionTreeClassifier()
Dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print(accuracy_score(y_train, Dtc.predict(x_train)))
Dtc_acc = accuracy_score(y_test, Dtc.predict(x_test))
print(Dtc_acc)
print (confusion_matrix(y_test,Dtc.predict(x_test)))
print (classification_report(y_test,Dtc.predict(x_test)))
# Out:
# 1.0
# 0.8974358974358975
# [[ 9  1]
#  [ 3 26]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.90      0.82        10
#            1       0.96      0.90      0.93        29
#
#     accuracy                           0.90        39
#    macro avg       0.86      0.90      0.87        39
# weighted avg       0.91      0.90      0.90        39

# %%
#Overfitting 
Grid_Parameters = {
    'criterion':['gini','entropy'],
    'max_depth':[3,5,7,10],
    'splitter':['best','random'],
    'min_samples_leaf':[1,2,3,5,7],
    'min_samples_split':[2,3,5,7],
    'max_features':['sqrt','log2']
}

grid_search_Dtc=GridSearchCV(Dtc,Grid_Parameters,cv=5,n_jobs=-1,verbose=1)
grid_search_Dtc.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 640 candidates, totalling 3200 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 7, 10],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 3, 5, 7],
#                          'min_samples_split': [2, 3, 5, 7],
#                          'splitter': ['best', 'random']},
#              verbose=1)

# %%
grid_search_Dtc.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 5,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 2,
#  'min_samples_split': 3,
#  'splitter': 'best'}

# %%
grid_search_Dtc.best_score_
# Out:
# np.float64(0.8971774193548387)

# %%
Dtc = DecisionTreeClassifier(criterion= 'gini', max_depth = 10, max_features = 'sqrt', min_samples_leaf =1, min_samples_split = 5, splitter ='best')
Dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, max_features='sqrt', min_samples_split=5)

# %%
print(accuracy_score(y_train, Dtc.predict(x_train)))
Dtc_acc = accuracy_score(y_test, Dtc.predict(x_test))
print(Dtc_acc)
print (confusion_matrix(y_test,Dtc.predict(x_test)))
print (classification_report(y_test,Dtc.predict(x_test)))
# Out:
# 0.9871794871794872
# 0.8974358974358975
# [[ 8  2]
#  [ 2 27]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80        10
#            1       0.93      0.93      0.93        29
#
#     accuracy                           0.90        39
#    macro avg       0.87      0.87      0.87        39
# weighted avg       0.90      0.90      0.90        39

# %%
ran_for = RandomForestClassifier(criterion= 'gini', max_depth = 10, max_features = 'sqrt', min_samples_leaf =1, min_samples_split = 5)
ran_for.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_split=5)

# %%
print(accuracy_score(y_train, ran_for.predict(x_train)))
ran_for_acc = accuracy_score(y_test, ran_for.predict(x_test))
print(ran_for_acc)
print (confusion_matrix(y_test,ran_for.predict(x_test)))
print (classification_report(y_test,ran_for.predict(x_test)))
# Out:
# 1.0
# 0.9230769230769231
# [[ 8  2]
#  [ 1 28]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84        10
#            1       0.93      0.97      0.95        29
#
#     accuracy                           0.92        39
#    macro avg       0.91      0.88      0.90        39
# weighted avg       0.92      0.92      0.92        39

# %%
from sklearn.neighbors import KNeighborsClassifier
Knn=KNeighborsClassifier()
Knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
print(accuracy_score(y_train, Knn.predict(x_train)))
Knn_acc = accuracy_score(y_test, Knn.predict(x_test))
print(Knn_acc)
print (confusion_matrix(y_test,Knn.predict(x_test)))
print (classification_report(y_test,Knn.predict(x_test)))
# Out:
# 0.9615384615384616
# 0.9230769230769231
# [[ 7  3]
#  [ 0 29]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.70      0.82        10
#            1       0.91      1.00      0.95        29
#
#     accuracy                           0.92        39
#    macro avg       0.95      0.85      0.89        39
# weighted avg       0.93      0.92      0.92        39

# %%
#models data frame 
lmodels = pd.DataFrame({ 'Model':['Logis', 'Kneigh','dec_tree','ran_forest'],
                       'score':[logi_acc,Knn_acc,Dtc_acc,ran_for_acc]})
lmodels.sort_values(by='score',ascending=False)
# Out:
#         Model     score
# 1      Kneigh  0.923077
# 3  ran_forest  0.923077
# 2    dec_tree  0.897436
# 0       Logis  0.846154

# %%
import pickle
lmodel = Knn_acc
pickle.dump(lmodel,open('parkinsons.pkl','wb'))

# %%
import pickle
with open("parkinsons_new.pkl", "wb") as m:
    pickle.dump(Knn_acc, m)
